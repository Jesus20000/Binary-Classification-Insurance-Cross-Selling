# %% [markdown]
# # Binary Classification of Insurance Cross Selling

# %% [markdown]
# **My Goal: The objective of this competition is to predict which customers respond positively to an automobile insurance offer.**

# %% [markdown]
# *Dataset Description:*
#
# **id:** A unique identifier for each student.
#
# **Gender:** The gender of the customer.
#
# **Age:** The age of the customer.
#
# **Driving_License:** Indicates whether the customer has a driver's license (1 = yes, 0 = no).
#
# **Region_Code:** A unique code representing the customer's region.
#
# **Previously_Insured:** Indicates whether the customer already has vehicle insurance (1 = yes, 0 = no).
#
# **Vehicle_Age:** The age of the vehicle.
#
# **Vehicle_Damage:** Indicates if the customer has had vehicle damage in the past (1 = yes, 0 = no).
#
# **Annual_Premium:** The annual premium amount the customer needs to pay.
#
# **Policy_Sales_Channel:** An anonymized code for various customer outreach channels, such as agents, email, phone calls, etc.
#
# **Vintage:** The number of days the customer has been associated with the insurance company.
#
# **Response:** The target variable indicating whether the customer is interested (1 = Interested, 0 = Not Interested).

# %% [markdown]
# # 1. Reading the dataset and getting some information

# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import roc_auc_score
import xgboost as xgb
from catboost import CatBoostClassifier
import optuna
from sklearn.model_selection import cross_val_score
from xgboost import XGBClassifier

# %%
train = pd.read_csv(r'C:\Users\isa.zeynalov\Desktop\Binary Classification of Insurance Cross Selling\train.csv')
test = pd.read_csv(r'C:\Users\isa.zeynalov\Desktop\Binary Classification of Insurance Cross Selling\test.csv')

# %%
train
# Out:
#                 id  Gender  Age  Driving_License  Region_Code  \
# 0                0    Male   21                1         35.0
# 1                1    Male   43                1         28.0
# 2                2  Female   25                1         14.0
# 3                3  Female   35                1          1.0
# 4                4  Female   36                1         15.0
# ...            ...     ...  ...              ...          ...
# 11504793  11504793    Male   48                1          6.0
# 11504794  11504794  Female   26                1         36.0
# 11504795  11504795  Female   29                1         32.0
# 11504796  11504796  Female   51                1         28.0
# 11504797  11504797    Male   25                1         28.0
#
#           Previously_Insured Vehicle_Age Vehicle_Damage  Annual_Premium  \
# 0                          0    1-2 Year            Yes         65101.0
# 1                          0   > 2 Years            Yes         58911.0
# 2                          1    < 1 Year             No         38043.0
# 3                          0    1-2 Year            Yes          2630.0
# 4                          1    1-2 Year             No         31951.0
# ...                      ...         ...            ...             ...
# 11504793                   0    1-2 Year            Yes         27412.0
# 11504794                   0    < 1 Year            Yes         29509.0
# 11504795                   1    < 1 Year             No          2630.0
# 11504796                   0    1-2 Year            Yes         48443.0
# 11504797                   1    < 1 Year             No         32855.0
#
#           Policy_Sales_Channel  Vintage  Response
# 0                        124.0      187         0
# 1                         26.0      288         1
# 2                        152.0      254         0
# 3                        156.0       76         0
# 4                        152.0      294         0
# ...                        ...      ...       ...
# 11504793                  26.0      218         0
# 11504794                 152.0      115         1
# 11504795                 152.0      189         0
# 11504796                  26.0      274         1
# 11504797                 152.0      189         0
#
# [11504798 rows x 12 columns]

# %%
train = train.drop(columns=['id'])
test = test.drop(columns=['id'])

# %%
desc = pd.DataFrame(index = list(train))
desc['type'] = train.dtypes
desc['count'] = train.count()
desc['nunique'] = train.nunique()
desc['%unique'] = desc['nunique'] /len(train) * 100
desc['null'] = train.isnull().sum()
desc['%null'] = desc['null'] / len(train) * 100
desc = pd.concat([desc,train.describe().T.drop('count',axis=1)],axis=1)
desc.sort_values(by=['type','null']).style.background_gradient(axis=0)
# Out:
# <style type="text/css">
# #T_f081d_row0_col1, #T_f081d_row0_col2, #T_f081d_row0_col3, #T_f081d_row0_col4, #T_f081d_row0_col5, #T_f081d_row0_col6, #T_f081d_row0_col7, #T_f081d_row0_col9, #T_f081d_row0_col10, #T_f081d_row0_col11, #T_f081d_row0_col12, #T_f081d_row1_col1, #T_f081d_row1_col2, #T_f081d_row1_col3, #T_f081d_row1_col4, #T_f081d_row1_col5, #T_f081d_row1_col6, #T_f081d_row1_col7, #T_f081d_row1_col8, #T_f081d_row1_col9, #T_f081d_row1_col10, #T_f081d_row1_col11, #T_f081d_row1_col12, #T_f081d_row2_col1, #T_f081d_row2_col2, #T_f081d_row2_col3, #T_f081d_row2_col4, #T_f081d_row2_col5, #T_f081d_row2_col6, #T_f081d_row2_col7, #T_f081d_row2_col8, #T_f081d_row2_col9, #T_f081d_row2_col10, #T_f081d_row2_col11, #T_f081d_row2_col12, #T_f081d_row3_col1, #T_f081d_row3_col4, #T_f081d_row3_col5, #T_f081d_row3_col8, #T_f081d_row3_col12, #T_f081d_row4_col1, #T_f081d_row4_col2, #T_f081d_row4_col3, #T_f081d_row4_col4, #T_f081d_row4_col5, #T_f081d_row4_col6, #T_f081d_row4_col7, #T_f081d_row4_col8, #T_f081d_row4_col9, #T_f081d_row4_col10, #T_f081d_row4_col11, #T_f081d_row4_col12, #T_f081d_row5_col1, #T_f081d_row5_col2, #T_f081d_row5_col3, #T_f081d_row5_col4, #T_f081d_row5_col5, #T_f081d_row5_col6, #T_f081d_row5_col7, #T_f081d_row5_col8, #T_f081d_row5_col9, #T_f081d_row5_col10, #T_f081d_row5_col11, #T_f081d_row5_col12, #T_f081d_row6_col1, #T_f081d_row6_col4, #T_f081d_row6_col5, #T_f081d_row7_col1, #T_f081d_row7_col2, #T_f081d_row7_col3, #T_f081d_row7_col4, #T_f081d_row7_col5, #T_f081d_row7_col6, #T_f081d_row7_col7, #T_f081d_row7_col8, #T_f081d_row7_col9, #T_f081d_row7_col11, #T_f081d_row7_col12, #T_f081d_row8_col1, #T_f081d_row8_col2, #T_f081d_row8_col3, #T_f081d_row8_col4, #T_f081d_row8_col5, #T_f081d_row9_col1, #T_f081d_row9_col2, #T_f081d_row9_col3, #T_f081d_row9_col4, #T_f081d_row9_col5, #T_f081d_row10_col1, #T_f081d_row10_col2, #T_f081d_row10_col3, #T_f081d_row10_col4, #T_f081d_row10_col5 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_f081d_row0_col8, #T_f081d_row3_col2, #T_f081d_row3_col3, #T_f081d_row3_col6, #T_f081d_row3_col7, #T_f081d_row3_col9, #T_f081d_row3_col10, #T_f081d_row3_col11, #T_f081d_row7_col10 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_f081d_row6_col2, #T_f081d_row6_col3, #T_f081d_row6_col6, #T_f081d_row6_col7, #T_f081d_row6_col8, #T_f081d_row6_col9, #T_f081d_row6_col10, #T_f081d_row6_col11, #T_f081d_row6_col12 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_f081d_row8_col6, #T_f081d_row8_col7, #T_f081d_row8_col8, #T_f081d_row8_col9, #T_f081d_row8_col10, #T_f081d_row8_col11, #T_f081d_row8_col12, #T_f081d_row9_col6, #T_f081d_row9_col7, #T_f081d_row9_col8, #T_f081d_row9_col9, #T_f081d_row9_col10, #T_f081d_row9_col11, #T_f081d_row9_col12, #T_f081d_row10_col6, #T_f081d_row10_col7, #T_f081d_row10_col8, #T_f081d_row10_col9, #T_f081d_row10_col10, #T_f081d_row10_col11, #T_f081d_row10_col12 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f081d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f081d_level0_col0" class="col_heading level0 col0" >type</th>
#       <th id="T_f081d_level0_col1" class="col_heading level0 col1" >count</th>
#       <th id="T_f081d_level0_col2" class="col_heading level0 col2" >nunique</th>
#       <th id="T_f081d_level0_col3" class="col_heading level0 col3" >%unique</th>
#       <th id="T_f081d_level0_col4" class="col_heading level0 col4" >null</th>
#       <th id="T_f081d_level0_col5" class="col_heading level0 col5" >%null</th>
#       <th id="T_f081d_level0_col6" class="col_heading level0 col6" >mean</th>
#       <th id="T_f081d_level0_col7" class="col_heading level0 col7" >std</th>
#       <th id="T_f081d_level0_col8" class="col_heading level0 col8" >min</th>
#       <th id="T_f081d_level0_col9" class="col_heading level0 col9" >25%</th>
#       <th id="T_f081d_level0_col10" class="col_heading level0 col10" >50%</th>
#       <th id="T_f081d_level0_col11" class="col_heading level0 col11" >75%</th>
#       <th id="T_f081d_level0_col12" class="col_heading level0 col12" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f081d_level0_row0" class="row_heading level0 row0" >Age</th>
#       <td id="T_f081d_row0_col0" class="data row0 col0" >int64</td>
#       <td id="T_f081d_row0_col1" class="data row0 col1" >11504798</td>
#       <td id="T_f081d_row0_col2" class="data row0 col2" >66</td>
#       <td id="T_f081d_row0_col3" class="data row0 col3" >0.000574</td>
#       <td id="T_f081d_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_f081d_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_f081d_row0_col6" class="data row0 col6" >38.383563</td>
#       <td id="T_f081d_row0_col7" class="data row0 col7" >14.993459</td>
#       <td id="T_f081d_row0_col8" class="data row0 col8" >20.000000</td>
#       <td id="T_f081d_row0_col9" class="data row0 col9" >24.000000</td>
#       <td id="T_f081d_row0_col10" class="data row0 col10" >36.000000</td>
#       <td id="T_f081d_row0_col11" class="data row0 col11" >49.000000</td>
#       <td id="T_f081d_row0_col12" class="data row0 col12" >85.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f081d_level0_row1" class="row_heading level0 row1" >Driving_License</th>
#       <td id="T_f081d_row1_col0" class="data row1 col0" >int64</td>
#       <td id="T_f081d_row1_col1" class="data row1 col1" >11504798</td>
#       <td id="T_f081d_row1_col2" class="data row1 col2" >2</td>
#       <td id="T_f081d_row1_col3" class="data row1 col3" >0.000017</td>
#       <td id="T_f081d_row1_col4" class="data row1 col4" >0</td>
#       <td id="T_f081d_row1_col5" class="data row1 col5" >0.000000</td>
#       <td id="T_f081d_row1_col6" class="data row1 col6" >0.998022</td>
#       <td id="T_f081d_row1_col7" class="data row1 col7" >0.044431</td>
#       <td id="T_f081d_row1_col8" class="data row1 col8" >0.000000</td>
#       <td id="T_f081d_row1_col9" class="data row1 col9" >1.000000</td>
#       <td id="T_f081d_row1_col10" class="data row1 col10" >1.000000</td>
#       <td id="T_f081d_row1_col11" class="data row1 col11" >1.000000</td>
#       <td id="T_f081d_row1_col12" class="data row1 col12" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f081d_level0_row2" class="row_heading level0 row2" >Previously_Insured</th>
#       <td id="T_f081d_row2_col0" class="data row2 col0" >int64</td>
#       <td id="T_f081d_row2_col1" class="data row2 col1" >11504798</td>
#       <td id="T_f081d_row2_col2" class="data row2 col2" >2</td>
#       <td id="T_f081d_row2_col3" class="data row2 col3" >0.000017</td>
#       <td id="T_f081d_row2_col4" class="data row2 col4" >0</td>
#       <td id="T_f081d_row2_col5" class="data row2 col5" >0.000000</td>
#       <td id="T_f081d_row2_col6" class="data row2 col6" >0.462997</td>
#       <td id="T_f081d_row2_col7" class="data row2 col7" >0.498629</td>
#       <td id="T_f081d_row2_col8" class="data row2 col8" >0.000000</td>
#       <td id="T_f081d_row2_col9" class="data row2 col9" >0.000000</td>
#       <td id="T_f081d_row2_col10" class="data row2 col10" >0.000000</td>
#       <td id="T_f081d_row2_col11" class="data row2 col11" >1.000000</td>
#       <td id="T_f081d_row2_col12" class="data row2 col12" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f081d_level0_row3" class="row_heading level0 row3" >Vintage</th>
#       <td id="T_f081d_row3_col0" class="data row3 col0" >int64</td>
#       <td id="T_f081d_row3_col1" class="data row3 col1" >11504798</td>
#       <td id="T_f081d_row3_col2" class="data row3 col2" >290</td>
#       <td id="T_f081d_row3_col3" class="data row3 col3" >0.002521</td>
#       <td id="T_f081d_row3_col4" class="data row3 col4" >0</td>
#       <td id="T_f081d_row3_col5" class="data row3 col5" >0.000000</td>
#       <td id="T_f081d_row3_col6" class="data row3 col6" >163.897744</td>
#       <td id="T_f081d_row3_col7" class="data row3 col7" >79.979531</td>
#       <td id="T_f081d_row3_col8" class="data row3 col8" >10.000000</td>
#       <td id="T_f081d_row3_col9" class="data row3 col9" >99.000000</td>
#       <td id="T_f081d_row3_col10" class="data row3 col10" >166.000000</td>
#       <td id="T_f081d

# %%
desc = pd.DataFrame(index = list(test))
desc['type'] = test.dtypes
desc['count'] = test.count()
desc['nunique'] = test.nunique()
desc['%unique'] = desc['nunique'] /len(test) * 100
desc['null'] = test.isnull().sum()
desc['%null'] = desc['null'] / len(test) * 100
desc = pd.concat([desc,test.describe().T.drop('count',axis=1)],axis=1)
desc.sort_values(by=['type','null']).style.background_gradient(axis=0)
# Out:
# <style type="text/css">
# #T_8df2c_row0_col1, #T_8df2c_row0_col2, #T_8df2c_row0_col3, #T_8df2c_row0_col4, #T_8df2c_row0_col5, #T_8df2c_row0_col6, #T_8df2c_row0_col7, #T_8df2c_row0_col9, #T_8df2c_row0_col10, #T_8df2c_row0_col11, #T_8df2c_row0_col12, #T_8df2c_row1_col1, #T_8df2c_row1_col2, #T_8df2c_row1_col3, #T_8df2c_row1_col4, #T_8df2c_row1_col5, #T_8df2c_row1_col6, #T_8df2c_row1_col7, #T_8df2c_row1_col8, #T_8df2c_row1_col9, #T_8df2c_row1_col10, #T_8df2c_row1_col11, #T_8df2c_row1_col12, #T_8df2c_row2_col1, #T_8df2c_row2_col2, #T_8df2c_row2_col3, #T_8df2c_row2_col4, #T_8df2c_row2_col5, #T_8df2c_row2_col6, #T_8df2c_row2_col7, #T_8df2c_row2_col8, #T_8df2c_row2_col9, #T_8df2c_row2_col10, #T_8df2c_row2_col11, #T_8df2c_row2_col12, #T_8df2c_row3_col1, #T_8df2c_row3_col4, #T_8df2c_row3_col5, #T_8df2c_row3_col8, #T_8df2c_row3_col12, #T_8df2c_row4_col1, #T_8df2c_row4_col2, #T_8df2c_row4_col3, #T_8df2c_row4_col4, #T_8df2c_row4_col5, #T_8df2c_row4_col6, #T_8df2c_row4_col7, #T_8df2c_row4_col8, #T_8df2c_row4_col9, #T_8df2c_row4_col10, #T_8df2c_row4_col11, #T_8df2c_row4_col12, #T_8df2c_row5_col1, #T_8df2c_row5_col4, #T_8df2c_row5_col5, #T_8df2c_row6_col1, #T_8df2c_row6_col2, #T_8df2c_row6_col3, #T_8df2c_row6_col4, #T_8df2c_row6_col5, #T_8df2c_row6_col6, #T_8df2c_row6_col7, #T_8df2c_row6_col8, #T_8df2c_row6_col9, #T_8df2c_row6_col11, #T_8df2c_row6_col12, #T_8df2c_row7_col1, #T_8df2c_row7_col2, #T_8df2c_row7_col3, #T_8df2c_row7_col4, #T_8df2c_row7_col5, #T_8df2c_row8_col1, #T_8df2c_row8_col2, #T_8df2c_row8_col3, #T_8df2c_row8_col4, #T_8df2c_row8_col5, #T_8df2c_row9_col1, #T_8df2c_row9_col2, #T_8df2c_row9_col3, #T_8df2c_row9_col4, #T_8df2c_row9_col5 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_8df2c_row0_col8, #T_8df2c_row3_col2, #T_8df2c_row3_col3, #T_8df2c_row3_col6, #T_8df2c_row3_col7, #T_8df2c_row3_col9, #T_8df2c_row3_col10, #T_8df2c_row3_col11, #T_8df2c_row6_col10 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_8df2c_row5_col2, #T_8df2c_row5_col3, #T_8df2c_row5_col6, #T_8df2c_row5_col7, #T_8df2c_row5_col8, #T_8df2c_row5_col9, #T_8df2c_row5_col10, #T_8df2c_row5_col11, #T_8df2c_row5_col12 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_8df2c_row7_col6, #T_8df2c_row7_col7, #T_8df2c_row7_col8, #T_8df2c_row7_col9, #T_8df2c_row7_col10, #T_8df2c_row7_col11, #T_8df2c_row7_col12, #T_8df2c_row8_col6, #T_8df2c_row8_col7, #T_8df2c_row8_col8, #T_8df2c_row8_col9, #T_8df2c_row8_col10, #T_8df2c_row8_col11, #T_8df2c_row8_col12, #T_8df2c_row9_col6, #T_8df2c_row9_col7, #T_8df2c_row9_col8, #T_8df2c_row9_col9, #T_8df2c_row9_col10, #T_8df2c_row9_col11, #T_8df2c_row9_col12 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8df2c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8df2c_level0_col0" class="col_heading level0 col0" >type</th>
#       <th id="T_8df2c_level0_col1" class="col_heading level0 col1" >count</th>
#       <th id="T_8df2c_level0_col2" class="col_heading level0 col2" >nunique</th>
#       <th id="T_8df2c_level0_col3" class="col_heading level0 col3" >%unique</th>
#       <th id="T_8df2c_level0_col4" class="col_heading level0 col4" >null</th>
#       <th id="T_8df2c_level0_col5" class="col_heading level0 col5" >%null</th>
#       <th id="T_8df2c_level0_col6" class="col_heading level0 col6" >mean</th>
#       <th id="T_8df2c_level0_col7" class="col_heading level0 col7" >std</th>
#       <th id="T_8df2c_level0_col8" class="col_heading level0 col8" >min</th>
#       <th id="T_8df2c_level0_col9" class="col_heading level0 col9" >25%</th>
#       <th id="T_8df2c_level0_col10" class="col_heading level0 col10" >50%</th>
#       <th id="T_8df2c_level0_col11" class="col_heading level0 col11" >75%</th>
#       <th id="T_8df2c_level0_col12" class="col_heading level0 col12" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8df2c_level0_row0" class="row_heading level0 row0" >Age</th>
#       <td id="T_8df2c_row0_col0" class="data row0 col0" >int64</td>
#       <td id="T_8df2c_row0_col1" class="data row0 col1" >7669866</td>
#       <td id="T_8df2c_row0_col2" class="data row0 col2" >66</td>
#       <td id="T_8df2c_row0_col3" class="data row0 col3" >0.000861</td>
#       <td id="T_8df2c_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_8df2c_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_8df2c_row0_col6" class="data row0 col6" >38.391369</td>
#       <td id="T_8df2c_row0_col7" class="data row0 col7" >14.999507</td>
#       <td id="T_8df2c_row0_col8" class="data row0 col8" >20.000000</td>
#       <td id="T_8df2c_row0_col9" class="data row0 col9" >24.000000</td>
#       <td id="T_8df2c_row0_col10" class="data row0 col10" >36.000000</td>
#       <td id="T_8df2c_row0_col11" class="data row0 col11" >49.000000</td>
#       <td id="T_8df2c_row0_col12" class="data row0 col12" >85.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8df2c_level0_row1" class="row_heading level0 row1" >Driving_License</th>
#       <td id="T_8df2c_row1_col0" class="data row1 col0" >int64</td>
#       <td id="T_8df2c_row1_col1" class="data row1 col1" >7669866</td>
#       <td id="T_8df2c_row1_col2" class="data row1 col2" >2</td>
#       <td id="T_8df2c_row1_col3" class="data row1 col3" >0.000026</td>
#       <td id="T_8df2c_row1_col4" class="data row1 col4" >0</td>
#       <td id="T_8df2c_row1_col5" class="data row1 col5" >0.000000</td>
#       <td id="T_8df2c_row1_col6" class="data row1 col6" >0.998021</td>
#       <td id="T_8df2c_row1_col7" class="data row1 col7" >0.044444</td>
#       <td id="T_8df2c_row1_col8" class="data row1 col8" >0.000000</td>
#       <td id="T_8df2c_row1_col9" class="data row1 col9" >1.000000</td>
#       <td id="T_8df2c_row1_col10" class="data row1 col10" >1.000000</td>
#       <td id="T_8df2c_row1_col11" class="data row1 col11" >1.000000</td>
#       <td id="T_8df2c_row1_col12" class="data row1 col12" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8df2c_level0_row2" class="row_heading level0 row2" >Previously_Insured</th>
#       <td id="T_8df2c_row2_col0" class="data row2 col0" >int64</td>
#       <td id="T_8df2c_row2_col1" class="data row2 col1" >7669866</td>
#       <td id="T_8df2c_row2_col2" class="data row2 col2" >2</td>
#       <td id="T_8df2c_row2_col3" class="data row2 col3" >0.000026</td>
#       <td id="T_8df2c_row2_col4" class="data row2 col4" >0</td>
#       <td id="T_8df2c_row2_col5" class="data row2 col5" >0.000000</td>
#       <td id="T_8df2c_row2_col6" class="data row2 col6" >0.463077</td>
#       <td id="T_8df2c_row2_col7" class="data row2 col7" >0.498635</td>
#       <td id="T_8df2c_row2_col8" class="data row2 col8" >0.000000</td>
#       <td id="T_8df2c_row2_col9" class="data row2 col9" >0.000000</td>
#       <td id="T_8df2c_row2_col10" class="data row2 col10" >0.000000</td>
#       <td id="T_8df2c_row2_col11" class="data row2 col11" >1.000000</td>
#       <td id="T_8df2c_row2_col12" class="data row2 col12" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8df2c_level0_row3" class="row_heading level0 row3" >Vintage</th>
#       <td id="T_8df2c_row3_col0" class="data row3 col0" >int64</td>
#       <td id="T_8df2c_row3_col1" class="data row3 col1" >7669866</td>
#       <td id="T_8df2c_row3_col2" class="data row3 col2" >290</td>
#       <td id="T_8df2c_row3_col3" class="data row3 col3" >0.003781</td>
#       <td id="T_8df2c_row3_col4" class="data row3 col4" >0</td>
#       <td id="T_8df2c_row3_col5" class="data row3 col5" >0.000000</td>
#       <td id="T_8df2c_row3_col6" class="data row3 col6" >163.899577</td>
#       <td id="T_8df2c_row3_col7" class="data row3 col7" >79.984449</td>
#       <td id="T_8df2c_row3_col8" class="data row3 col8" >10.000000</td>
#       <td id="T_8df2c_row3_col9" class="data row3 col9" >99.000000</td>
#       <td id="T_8df2c_row3_col10" class="data row3 col10" >166.000000</td>
#       <td id="T_8df2c_row3_col11" class="data row3 col11" >232.000000</td>
#       <td id="T_8df2c_row3_col12" class="data row3 col12" >299.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8df2c_level0_row4" class="row_heading level0 row4" >Region_Code</th>
#       <td id="T_8df2c_row4

# %%
categorical_columns = train.select_dtypes(include=['object']).columns
unique_counts = train[categorical_columns].nunique()
print(unique_counts)
# Out:
# Gender            2
# Vehicle_Age       3
# Vehicle_Damage    2
# dtype: int64

# %%
train.Gender.value_counts(normalize=True)
# Out:
# Gender
# Male      0.541351
# Female    0.458649
# Name: proportion, dtype: float64

# %%
train.Vehicle_Damage.value_counts(normalize=True)
# Out:
# Vehicle_Damage
# Yes    0.50268
# No     0.49732
# Name: proportion, dtype: float64

# %%
train.Vehicle_Age.value_counts(normalize=True)
# Out:
# Vehicle_Age
# 1-2 Year     0.520016
# < 1 Year     0.438438
# > 2 Years    0.041546
# Name: proportion, dtype: float64

# %% [markdown]
# # EDA

# %%
gender_counts = train['Gender'].value_counts()
plt.figure(figsize=(6, 6))
plt.pie(gender_counts, labels=gender_counts, autopct='%1.1f%%', colors=['skyblue', 'lightcoral'], startangle=90)
plt.title('Gender Distribution')
plt.show()

# %%
response_counts = train['Response'].value_counts()
plt.figure(figsize=(6, 6))
plt.pie(response_counts, labels=['No Response', 'Positive Response'], autopct='%1.1f%%', colors=['lightcoral', 'lightgreen'], startangle=90)
plt.title('Response Proportions')
plt.show()

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.histplot(train['Age'], bins=30, kde=True, color='blue')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x='Driving_License', data=train, palette='Set2')
plt.title('Driving License Distribution')
plt.xlabel('Driving License (0 = No, 1 = Yes)')
plt.ylabel('Count')
plt.show()

# %%
numerical_cols = ['Age', 'Driving_License', 'Region_Code', 'Previously_Insured', 
                  'Policy_Sales_Channel', 'Vintage', 'Response']
plt.figure(figsize=(12, 8))
sns.boxplot(data=train[numerical_cols], orient='h', palette='Set2')
plt.title('Distribution of Numerical Variables')
plt.xlabel('Value')
plt.show()

# %%
correlation_matrix = train[numerical_cols].corr()
plt.figure(figsize=(20, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".1f", linewidths=0.1)
#plt.gcf().set_facecolor('skyblue')  
plt.title('Correlation Matrix')
plt.show()

# %%
def convert_vehicle_age(age_str):
    if isinstance(age_str, str):
        if '< 1 Year' in age_str:
            return 0
        elif '1-2 Year' in age_str:
            return 1
        elif '> 2 Years' in age_str:
            return 2
    return None

train['Vehicle_Age'] = train['Vehicle_Age'].apply(convert_vehicle_age)
train.head()
# Out:
#    Gender  Age  Driving_License  Region_Code  Previously_Insured  Vehicle_Age  \
# 0    Male   21                1         35.0                   0            1
# 1    Male   43                1         28.0                   0            2
# 2  Female   25                1         14.0                   1            0
# 3  Female   35                1          1.0                   0            1
# 4  Female   36                1         15.0                   1            1
#
#   Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  Response
# 0            Yes         65101.0                 124.0      187         0
# 1            Yes         58911.0                  26.0      288         1
# 2             No         38043.0                 152.0      254         0
# 3            Yes          2630.0                 156.0       76         0
# 4             No         31951.0                 152.0      294         0

# %%
label_encoder = LabelEncoder()
train['Gender'] = label_encoder.fit_transform(train['Gender'])
test['Gender'] = label_encoder.fit_transform(test['Gender'])
train['Vehicle_Damage'] = label_encoder.fit_transform(train['Vehicle_Damage'])
test['Vehicle_Damage'] = label_encoder.fit_transform(test['Vehicle_Damage'])
train.head()
# Out:
#    Gender  Age  Driving_License  Region_Code  Previously_Insured  Vehicle_Age  \
# 0       1   21                1         35.0                   0            1
# 1       1   43                1         28.0                   0            2
# 2       0   25                1         14.0                   1            0
# 3       0   35                1          1.0                   0            1
# 4       0   36                1         15.0                   1            1
#
#    Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  Response
# 0               1         65101.0                 124.0      187         0
# 1               1         58911.0                  26.0      288         1
# 2               0         38043.0                 152.0      254         0
# 3               1          2630.0                 156.0       76         0
# 4               0         31951.0                 152.0      294         0

# %%
categorical_columns
# Out:
# Index(['Gender', 'Vehicle_Age', 'Vehicle_Damage'], dtype='object')

# %%
train.corr()['Response']
# Out:
# Gender                  0.055212
# Age                     0.122134
# Driving_License         0.009197
# Region_Code             0.012816
# Previously_Insured     -0.345930
# Vehicle_Age             0.231029
# Vehicle_Damage          0.359780
# Annual_Premium          0.032261
# Policy_Sales_Channel   -0.152733
# Vintage                -0.015177
# Response                1.000000
# Name: Response, dtype: float64

# %%
# Separate features (X) and target variable (y)
X = train.loc[:, train.columns != "Response"]
y = train['Response']

# %%
# Standardize the features using StandardScaler
scaler = StandardScaler()

# Fit the scaler to the data
scaler.fit(X)

# Transform the data
X_scaled = scaler.transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=101)

# %%
def objective(trial):
    model_type = trial.suggest_categorical("model_type", ["xgboost", "catboost"])

    if model_type == "xgboost":
        params = {
            'n_estimators': trial.suggest_int('n_estimators', 50, 100),
            'max_depth': trial.suggest_int('max_depth', 3, 6),
            'learning_rate': trial.suggest_loguniform('learning_rate', 0.05, 0.2)
        }
        model = XGBClassifier(**params, random_state=101, use_label_encoder=False, eval_metric='auc')

    elif model_type == "catboost":
        params = {
            'iterations': trial.suggest_int('iterations', 50, 100),
            'depth': trial.suggest_int('depth', 3, 6),
            'learning_rate': trial.suggest_loguniform('learning_rate', 0.05, 0.2)
        }
        model = CatBoostClassifier(**params, random_state=101, verbose=0)

    auc = cross_val_score(model, X_train, y_train, cv=3, scoring='roc_auc').mean()
    return auc

study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=20)
# Out:
# [I 2024-08-23 10:39:29,812] A new study created in memory with name: no-name-ff9bbbd9-f382-4674-8d89-e29a5c27cd3e
# [I 2024-08-23 10:44:08,747] Trial 0 finished with value: 0.8718474688405108 and parameters: {'model_type': 'xgboost', 'n_estimators': 90, 'max_depth': 6, 'learning_rate': 0.10744301992566994}. Best is trial 0 with value: 0.8718474688405108.
# [I 2024-08-23 10:48:18,163] Trial 1 finished with value: 0.8597668972999598 and parameters: {'model_type': 'catboost', 'iterations': 64, 'depth': 5, 'learning_rate': 0.06359457045319736}. Best is trial 0 with value: 0.8718474688405108.
# [I 2024-08-23 10:49:28,957] Trial 2 finished with value: 0.8591922203225213 and parameters: {'model_type': 'xgboost', 'n_estimators': 59, 'max_depth': 5, 'learning_rate': 0.050475666820064706}. Best is trial 0 with value: 0.8718474688405108.
# [I 2024-08-23 10:51:51,665] Trial 3 finished with value: 0.8626860377265771 and parameters: {'model_type': 'catboost', 'iterations': 79, 'depth': 3, 'learning_rate': 0.1530432230983905}. Best is trial 0 with value: 0.8718474688405108.
# [I 2024-08-23 10:55:04,363] Trial 4 finished with value: 0.8581760934915331 and parameters: {'model_type': 'catboost', 'iterations': 76, 'depth': 4, 'learning_rate': 0.0563345057497585}. Best is trial 0 with value: 0.8718474688405108.
# [I 2024-08-23 10:56:34,165] Trial 5 finished with value: 0.8679406961327313 and parameters: {'model_type': 'xgboost', 'n_estimators': 76, 'max_depth': 4, 'learning_rate': 0.13686564155289957}. Best is trial 0 with value: 0.8718474688405108.
# [I 2024-08-23 10:59:26,673] Trial 6 finished with value: 0.8597976764161185 and parameters: {'model_type': 'catboost', 'iterations': 64, 'depth': 3, 'learning_rate': 0.12372980340928619}. Best is trial 0 with value: 0.8718474688405108.
# [I 2024-08-23 11:03:17,179] Trial 7 finished with value: 0.8629018866042487 and parameters: {'model_type': 'catboost', 'iterations': 77, 'depth': 5, 'learning_rate': 0.08900086256881977}. Best is trial 0 with value: 0.8718474688405108.
# [I 2024-08-23 11:05:23,092] Trial 8 finished with value: 0.8712750575543268 and parameters: {'model_type': 'xgboost', 'n_estimators': 89, 'max_depth': 5, 'learning_rate': 0.1358095798573706}. Best is trial 0 with value: 0.8718474688405108.
# [I 2024-08-23 11:08:32,528] Trial 9 finished with value: 0.861746066026828 and parameters: {'model_type': 'catboost', 'iterations': 67, 'depth': 6, 'learning_rate': 0.06320159775193177}. Best is trial 0 with value: 0.8718474688405108.
# [I 2024-08-23 11:10:36,816] Trial 10 finished with value: 0.8760089078958192 and parameters: {'model_type': 'xgboost', 'n_estimators': 94, 'max_depth': 6, 'learning_rate': 0.19230194689691033}. Best is trial 10 with value: 0.8760089078958192.
# [I 2024-08-23 11:13:00,698] Trial 11 finished with value: 0.8765362732293754 and parameters: {'model_type': 'xgboost', 'n_estimators': 100, 'max_depth': 6, 'learning_rate': 0.19113698520752934}. Best is trial 11 with value: 0.8765362732293754.
# [I 2024-08-23 11:15:28,707] Trial 12 finished with value: 0.8763267723582217 and parameters: {'model_type': 'xgboost', 'n_estimators': 100, 'max_depth': 6, 'learning_rate': 0.18666082601871892}. Best is trial 11 with value: 0.8765362732293754.
# [I 2024-08-23 11:17:12,978] Trial 13 finished with value: 0.868764088813356 and parameters: {'model_type': 'xgboost', 'n_estimators': 100, 'max_depth': 3, 'learning_rate': 0.1983410274494896}. Best is trial 11 with value: 0.8765362732293754.
# [I 2024-08-23 11:19:11,856] Trial 14 finished with value: 0.8745308764466747 and parameters: {'model_type': 'xgboost', 'n_estimators': 78, 'max_depth': 6, 'learning_rate': 0.17075281703294196}. Best is trial 11 with value: 0.8765362732293754.
# [I 2024-08-23 11:21:30,380] Trial 15 finished with value: 0.8711695017345816 and parameters: {'model_type': 'xgboost', 'n_estimators': 100, 'max_depth': 6, 'learning_rate': 0.08535331750217705}. Best is trial 11 with value: 0.8765362732293754.
# [I 2024-08-23 11:22:49,298] Trial 16 finished with value: 0.8682937234463063 and parameters: {'model_type': 'xgboost', 'n_estimators': 50, 'max_depth': 5, 'learning_rate': 0.164173463322427}. Best is trial 11 with value: 0.8765362732293754.
# [I 2024-08-23 11:24:27,311] Trial 17 finished with value: 0.8669342091985968 and parameters: {'model_type': 'xgboost', 'n_estimators': 82, 'max_depth': 4, 'learning_rate': 0.11332068136270596}. Best is trial 11 with value: 0.8765362732293754.
# [I 2024-08-23 11:26:12,599] Trial 18 finished with value: 0.8738122271676513 and parameters: {'model_type': 'xgboost', 'n_estimators': 67, 'max_depth': 6, 'learning_rate': 0.18089356676798943}. Best is trial 11 with value: 0.8765362732293754.
# [I 2024-08-23 11:28:04,174] Trial 19 finished with value: 0.8718352339945495 and parameters: {'model_type': 'xgboost', 'n_estimators': 85, 'max_depth': 5, 'learning_rate': 0.1531526435332861}. Best is trial 11 with value: 0.8765362732293754.

# %%
# Retrieve the best parameters
best_params = study.best_params
best_model_type = best_params.pop("model_type")

if best_model_type == "xgboost":
    best_model = XGBClassifier(**best_params, random_state=101, use_label_encoder=False, eval_metric='auc')
elif best_model_type == "catboost":
    best_model = CatBoostClassifier(**best_params, random_state=101, verbose=0)

best_model.fit(X_train, y_train)
y_pred = best_model.predict_proba(X_test)[:, 1]

# %%
# Plot ROC curve
from sklearn.metrics import roc_curve, auc
fpr, tpr, _ = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# %%
# Fit the best model to the entire training data
best_model.fit(X_train, y_train)

# Predict the probabilities for the test set
y_pred_proba = best_model.predict_proba(X_test)[:, 1]

# Calculate the ROC AUC score
roc_auc = roc_auc_score(y_test, y_pred_proba)
print(f"Final Model's ROC AUC Score: {roc_auc:.4f}")
# Out:
# Final Model's ROC AUC Score: 0.8764
